# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fm = pd.read_csv(r"C:\Users\KIIT\OneDrive\Desktop\PROJECT_ROOT\data\raw\fund_master.csv")
fm.head()
# Out:
#    amfi_code            fund_name category sub_category risk_grade
# 0     118834  HDFC Top 100 Direct   Equity    Large Cap       High
# 1     119551         SBI Bluechip   Equity    Large Cap       High
# 2     120503       ICICI Bluechip   Equity    Large Cap       High
# 3     119092        Axis Bluechip   Equity    Large Cap   Moderate
# 4     120841       Kotak Bluechip   Equity    Large Cap   Moderate

# %%
print(fm.shape)
print(fm.dtypes)
# Out:
# (5, 5)
# amfi_code        int64
# fund_name       object
# category        object
# sub_category    object
# risk_grade      object
# dtype: object

# %%
sns.countplot(x="category", data=fm)
plt.show()
